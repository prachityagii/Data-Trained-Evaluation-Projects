# %% [markdown]
# # Baseball Case Study
# Problem Statement:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.

# %% [markdown]
# # Importing required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Data Exploration

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# There are 30 rows and 17 columns present in our dataset.

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# all the columns have int and float data types therefore encoding is not required

# %%
# checking null values in the dataframe
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
# graphical representation of null values
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %% [markdown]
# There are no null values in the dataset

# %%
#find duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values in the dataset

# %%
# statistical summary
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# Observations:
# 1. Differences between min-25%,25%-50%,50%-75%,75%-max is not large so no problem (data is normally distributed)
# 2. There are no missing values present in our dataset
# 3. Std from the mean is less for all the columns it implies data is good/clean.

# %% [markdown]
# # Target variable

# %% [markdown]
# The Target column = W is a continous data and hence this is a Regression problem.

# %%
#count of each value
print(df['W'].value_counts())
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64

# %%
# graphical representation of count of each value
plt.hist(df['W'])
plt.xlabel('Wins')
plt.title('Distribution of Wins')

plt.show()

# %%
ax = sns.countplot(x="W",data=df)

# %% [markdown]
# Most of the wins have value count 1. Wins 74,76,81 and 83 have value count 2. Win 68 has value count 3.

# %% [markdown]
# # Checking Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
# plotting Heat Map

plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
corr_matrix = df.corr().abs()
corr_matrix["W"].sort_values(ascending=False)
# Out:
# W      1.000000
# ERA    0.819600
# RA     0.812952
# ER     0.809435
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# 3B     0.251118
# SB     0.157234
# SO     0.111850
# E      0.089485
# AB     0.087947
# CG     0.080533
# H      0.037612
# Name: W, dtype: float64

# %% [markdown]
# RA, ER & ERA are highly correlated with W and also correlated with each other.

# %% [markdown]
# # let's check the data distribution among all the columns

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,35),facecolor='yellow')
plotnumber= 1

for column in df:
    if plotnumber<=17:
        ax= plt.subplot(6,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# # Preprocessing

# %% [markdown]
# # Splitting the independent and target variables in x and y before removing the skewness

# %%
x = df.drop(columns=['W'])
y = df['W']

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %% [markdown]
# # Checking Skewness

# %%
x.skew().sort_values(ascending=False)
# Out:
# R      1.200786
# E      0.890132
# CG     0.736845
# H      0.670254
# SV     0.657524
# SHO    0.565790
# HR     0.516441
# SB     0.479893
# AB     0.183437
# BB     0.158498
# 3B     0.129502
# ER     0.058710
# ERA    0.053331
# RA     0.045734
# SO    -0.156065
# 2B    -0.230650
# dtype: float64

# %% [markdown]
# We can see skewness in some of the columns of our dataset, we will remove the skewness using power_transform function

# %%
from sklearn.preprocessing import power_transform
x_new = power_transform(x)

# %%
x_new
# Out:
# array([[ 7.28217745e-01,  8.58727497e-01,  4.99600361e-16,
#          1.47768528e+00,  1.03310301e+00, -7.64625858e-01,
#         -1.61091476e+00, -2.56989562e+00,  9.39708194e-01,
#         -6.60330958e-01, -4.97424688e-01, -5.00893458e-01,
#         -5.32211279e-01],
#        [-6.38701716e-01, -8.52436453e-01, -4.99600361e-16,
#         -8.48599687e-01,  5.02886597e-01, -4.35291761e-01,
#         -7.49579004e-01,  7.66543323e-01,  3.47127355e-02,
#          6.09165308e-01,  2.86805055e-01,  3.06388926e-01,
#         -9.09180538e-01, -1.39754579e+00, -1.66918711e-01,
#          2.22513385e-02],
#        [ 9.27444754e-01,  8.14690190e-01,  4.44089210e-16,
#         -8.62781610e-02,  1.61644394e+00,  7.68314134e-01,
#         -1.50694503e+00,  3.23749797e-01,  6.69020699e-01,
#          2.16161235e+00,  2.32407200e+00,  2.39132405e+00,
#          4.15267992e-01, -2.09932639e+00, -9.26809171e-01,
#          2.61503637e-01]])

# %%
# checking skewness
pd.DataFrame(x_new, columns= x.columns).skew().sort_values(ascending=False)
# Out:
# AB     0.090410
# E      0.063909
# SO     0.041170
# SHO    0.006560
# ERA    0.001746
# SV     0.000836
# H      0.000000
# HR    -0.000065
# ER    -0.001940
# BB    -0.007760
# RA    -0.008082
# SB    -0.010455
# 2B    -0.035315
# R     -0.055006
# CG    -0.059785
# 3B    -0.072933
# dtype: float64

# %%
x = pd.DataFrame(x_new, columns= x.columns)
x.skew().sort_values(ascending=False) # validating that skewness has been removed or not
# Out:
# AB     0.090410
# E      0.063909
# SO     0.041170
# SHO    0.006560
# ERA    0.001746
# SV     0.000836
# H      0.000000
# HR    -0.000065
# ER    -0.001940
# BB    -0.007760
# RA    -0.008082
# SB    -0.010455
# 2B    -0.035315
# R     -0.055006
# CG    -0.059785
# 3B    -0.072933
# dtype: float64

# %%
plt.figure(figsize=(20,35), facecolor='white')
plotnumber = 1

for column in x:
    if plotnumber<=17:
        ax= plt.subplot(6,3,plotnumber)
        sns.distplot(x[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# Skewness has been removed, now we can proceed with further steps.

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %% [markdown]
# # Checking outliers

# %%
# visualize the outliers using box plot
x.boxplot(figsize=[20,8]) 
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# There are negligible outliers in R, SHO and E therefore there is no need to remove the outliers.

# %%
#Visualizing relationship between feature and label (SCATTER PLOT)

plt.figure(figsize=(20,35))
plotnumber = 1

for column in x:
    if plotnumber<=16:
        ax= plt.subplot(6,3,plotnumber)
        sns.stripplot(y,x[column]) 
    plotnumber+=1
plt.show()

# %% [markdown]
# The relation of RA, ER & ERA are all negative with the target column with a similar weightage.

# %% [markdown]
# Let's proceed by checking multicollinearilty in the dependent variables. Before that we should scale our data, let's use the standard scaler for that.

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()
x_scaled = scalar.fit_transform(x)

# %%
x_scaled.shape
# Out:
# (30, 16)

# %% [markdown]
# now we will check for multicollinearity using VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['features'] = x.columns

#let's check the values
vif
# Out:
#             vif features
# 0     10.105172        R
# 1     13.097976       AB
# 2      7.691412        H
# 3      3.771955       2B
# 4      3.294036       3B
# 5     11.029874       HR
# 6      3.503707       BB
# 7      2.822950       SO
# 8      2.238197       SB
# 9    222.525272       RA
# 10  1966.569612       ER
# 11  1346.157088      ERA
# 12     2.506851       CG
# 13     3.343211      SHO
# 14     5.110873       SV
# 15     2.059791        E

# %% [markdown]
# columns ER, ERA have a very high VIF therefore we will remove these columns to remove the problem of multicollinearity

# %%
x = x.drop(columns=['ERA','ER'])

# %%
#Feature selection

#Using SelectKBest feature seleciton Method
from sklearn.feature_selection import SelectKBest,f_classif
best_features=SelectKBest(f_classif, k=14)
fit=best_features.fit(x,y)
df_scores=pd.DataFrame(fit.scores_)
df_columns=pd.DataFrame(x.columns)
#concatenate dataframes
feature_scores = pd.concat([df_columns,df_scores],axis=1)
#name output columns
feature_scores.columns = ['Feaure_Name','Score']
#print 17 best features
print(feature_scores.nlargest(14,'Score'))
# Out:
#    Feaure_Name     Score
# 13           E  4.270923
# 0            R  3.673599
# 9           RA  2.515997
# 8           SB  2.122715
# 12          SV  1.724399
# 1           AB  1.566922
# 7           SO  1.510752
# 5           HR  1.069737
# 6           BB  1.017882
# 11         SHO  0.954816
# 3           2B  0.889863
# 4           3B  0.828419
# 2            H  0.764949
# 10          CG  0.449082

# %% [markdown]
# Since column CG has the lowest score in SelectKBest, we will drop column CG

# %%
x = x.drop(columns=['CG'])

# %%
x.shape
# Out:
# (30, 13)

# %%
#Visualizing relationship between feature and label (SCATTER PLOT)

plt.figure(figsize=(20,35))
plotnumber = 1

for column in x:
    if plotnumber<=15:
        ax= plt.subplot(5,3,plotnumber)
        sns.stripplot(y,x[column]) 
    plotnumber+=1
plt.show()

# %% [markdown]
# # Applying Regression models and finding best fit model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

lr=LinearRegression()
from sklearn.metrics import r2_score
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.30,random_state=i)
    lr.fit(x_train,y_train)
    y_pred_train=lr.predict(x_train)
    y_pred=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(y_train,y_pred_train)}")
    print(f"At random state {i},the testing accuracy is:- {r2_score(y_test,y_pred)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 0.9835461850997687
# At random state 0,the testing accuracy is:- 0.049423057863485886
#
#
# At random state 1,the training accuracy is:- 0.9888284441636753
# At random state 1,the testing accuracy is:- 0.4514414138170243
#
#
# At random state 2,the training accuracy is:- 0.990547865936062
# At random state 2,the testing accuracy is:- -0.5018143448449774
#
#
# At random state 3,the training accuracy is:- 0.9716836489725161
# At random state 3,the testing accuracy is:- 0.5559793080735658
#
#
# At random state 4,the training accuracy is:- 0.9770180759177614
# At random state 4,the testing accuracy is:- 0.674704550551038
#
#
# At random state 5,the training accuracy is:- 0.9496229653200257
# At random state 5,the testing accuracy is:- 0.8866729379664523
#
#
# At random state 6,the training accuracy is:- 0.9578708874838016
# At random state 6,the testing accuracy is:- 0.7503239892189897
#
#
# At random state 7,the training accuracy is:- 0.9718721146571422
# At random state 7,the testing accuracy is:- 0.5827300861197628
#
#
# At random state 8,the training accuracy is:- 0.9865062698637251
# At random state 8,the testing accuracy is:- 0.17463431011924757
#
#
# At random state 9,the training accuracy is:- 0.9503225088512414
# At random state 9,the testing accuracy is:- 0.8274190470873042
#
#
# At random state 10,the training accuracy is:- 0.9733032340530868
# At random state 10,the testing accuracy is:- -0.05119513614021054
#
#
# At random state 11,the training accuracy is:- 0.9932120682204826
# At random state 11,the testing accuracy is:- -0.5431208228976365
#
#
# At random state 12,the training accuracy is:- 0.9818943281750816
# At random state 12,the testing accuracy is:- 0.06806121985794633
#
#
# At random state 13,the training accuracy is:- 0.9666792610480258
# At random state 13,the testing accuracy is:- 0.7512905742325524
#
#
# At random state 14,the training accuracy is:- 0.9701715183095152
# At random state 14,the testing accuracy is:- 0.4819591221742835
#
#
# At random state 15,the training accuracy is:- 0.9568630283748724
# At random state 15,the testing accuracy is:- 0.3203955861045542
#
#
# At random state 16,the training accuracy is:- 0.9841429984371626
# At random state 16,the testing accuracy is:- -0.23449974116997252
#
#
# At random state 17,the training accuracy is:- 0.9802019062476747
# At random state 17,the testing accuracy is:- -0.2840580894471374
#
#
# At random state 18,the training accuracy is:- 0.9767209812056998
# At random state 18,the testing accuracy is:- -0.38484803771889897
#
#
# At random state 19,the training accuracy is:- 0.9586966040749566
# At random state 19,the testing accuracy is:- 0.4395132417584342
#
#
# At random state 20,the training accuracy is:- 0.9762330975859861
# At random state 20,the testing accuracy is:- -0.38603758065929394
#
#
# At random state 21,the training accuracy is:- 0.9808787988080264
# At random state 21,the testing accuracy is:- -0.3821777833489002
#
#
# At random state 22,the training accuracy is:- 0.967338440837153
# At random state 22,the testing accuracy is:- 0.017441097960300023
#
#
# At random state 23,the training accuracy is:- 0.9941944029734799
# At random state 23,the testing accuracy is:- 0.5879151734287411
#
#
# At random state 24,the training accuracy is:- 0.9928528770217332
# At random state 24,the testing accuracy is:- -0.3967159550688286
#
#
# At random state 25,the training accuracy is:- 0.98722962651577
# At random state 25,the testing accuracy is:- -0.2185342354747637
#
#
# At random state 26,the training accuracy is:- 0.9820545509409642
# At random state 26,the testing accuracy is:- 0.25478038397587155
#
#
# At random state 27,the training accuracy is:- 0.9745407501708033
# At random state 27,the testing accuracy is:- 0.5669044227927642
#
#
# At random state 28,the training accuracy is:- 0.9779738671732114
# At random state 28,the testing accuracy is:- 0.6119867988553007
#
#
# At random state 29,the training accuracy is:- 0.9571653825784652
# At random state 29,the testing accuracy is:- 0.698064114045311
#
#
# At random state 30,the training accuracy is:- 0.9733894281426517
# At random state 30,the testing accuracy is:- 0.4511634173896305
#
#
# At random state 31,the training accuracy is:- 0.9898931110612491
# At random state 31,the testing accuracy is:- 0.23391164396824038
#
#
# At random state 32,the training accuracy is:- 0.9787897175689702
# At random state 32,the testing accuracy is:- 0.31327017113678446
#
#
# At random state 33,the training accuracy is:- 0.9731946010168132
# At random state 33,the testing accuracy is:- 0.7721360929350337
#
#
# At random state 34,the training accuracy is:- 0.9638211722073801
# At random state 34,the testing accuracy is:- 0.8301937233516746
#
#
# At random state 35,the training accuracy is:- 0.9703189599997554
# At random state 35,the testing accuracy is:- 0.4980941643099539
#
#
# At random state 36,the training accuracy is:- 0.9799113803280727
# At random state 36,the testing accuracy is:- 0.5948489909603167
#
#
# At random state 37,the training accuracy is:- 0.9645405622908878
# At random state 37,the testing accuracy is:- 0.4972527256802365
#
#
# At random state 38,the training accuracy is:- 0.9782982857147207
# At random state 38,the testing accuracy is:- 0.22320812981244753
#
#
# At random state 39,the training accuracy is:- 0.9432162297108181
# At random state 39,the testing accuracy is:- 0.7467036441642283
#
#
# At random state 40,the training accuracy is:- 0.9615329561426842
# At random state 40,the testing accuracy is:- 0.6695210300872401
#
#
# At random state 41,the training accuracy is:- 0.9855723637936498
# At random state 41,the testing accuracy is:- 0.041436084733410095
#
#
# At random state 42,the training accuracy is:- 0.9785358206292211
# At random state 42,the testing accuracy is:- 0.8208138538871522
#
#
# At random state 43,the training accuracy is:- 0.9799897210377174
# At random state 43,the testing accuracy is:- -0.5901971865534121
#
#
# At random state 44,the training accuracy is:- 0.982301862744692
# At random state 44,the testing accuracy is:- 0.6824293055335441
#
#
# At random state 45,the training accuracy is:- 0.9531541253886495
# At random state 45,the testing accuracy is:- 0.8472263332057227
#
#
# At random state 46,the training accuracy is:- 0.984536982773029
# At random state 46,the testing accuracy is:- 0.43218472383657336
#
#
# At random state 47,the training accuracy is:- 0.9657746344221665
# At random state 47,the testing accuracy is:- 0.6729317063600195
#
#
# At random state 48,the training accuracy is:- 0.9691625713485401
# At random state 48,the testing accuracy is:- 0.2626999807718342
#
#
# At random state 49,the training accuracy is:- 0.9964144442563172
# At random state 49,the testing accuracy is:- 0.13901262470034648
#
#
# At random state 50,the training accuracy is:- 0.9861534293934789
# At random state 50,the testing accuracy is:- 0.6602459985579019
#
#
# At random state 51,the training accuracy is:- 0.9723641549554463
# At random state 51,the testing accuracy is:- 0.5928571543236323
#
#
# At random state 52,the training accuracy is:- 0.9697573940460036
# At random state 52,the testing accuracy is:- 0.6092652144777859
#
#
# At random state 53,the training accuracy is:- 0.9736289103312668
# At random state 53,the testing accuracy is:- 0.5262250900573342
#
#
# At random state 54,the training accuracy is:- 0.9753898504455426
# At random state 54,the testing accuracy is:- 0.636252528372676
#
#
# At random state 55,the training accuracy is:- 0.955367945527797
# At random state 55,the testing accuracy is:- 0.37962984661431576
#
#
# At random state 56,the training accuracy is:- 0.9886951537410155
# At random state 56,the testing accuracy is:- -0.41126564983525626
#
#
# At random state 57,the training accuracy is:- 0.9661572981263132
# At random state 57,the testing accuracy is:- 0.06656801038597504
#
#
# At random state 58,the training accuracy is:- 0.9890218254639859
# At random state 58,the testing accuracy is:- 0.31818877572982385
#
#
# At random state 59,the training accuracy is:- 0.9798264089584818
# At random state 59,the testing accuracy is:- 0.3529751366534203
#
#
# At random state 60,the training accuracy is:- 0.9904605936620599
# At random state 60,the testing accuracy is:- -0.6870380393237401
#
#
# At random state 61,the training accuracy is:- 0.9905844625772511
# At random state 61,the testing accuracy is:- -0.8106522011410044
#
#
# At random state 62,the training accuracy is:- 0.9914818094628893
# At random state 62,the testing accuracy is:- -2.4778059917022612
#
#
# At random state 63,the training accuracy is:- 0.9736349816931261
# At random state 63,the testing accuracy is:- -0.598420806516268
#
#
# At random state 64,the training accuracy is:- 0.9524289448916643
# At random state 64,the testing accuracy is:- 0.784190517650511
#
#
# At random state 65,the training accuracy is:- 0.9594752473734577
# At random state 65,the testing accuracy is:- 0.32352728989820223
#
#
# At random state 66,the training accuracy is:- 0.9847601361840962
# At random state 66,the testing accuracy is:- 0.345244746665607
#
#
# At random state 67,the training accuracy is:- 0.9615832592241585
# At random state 67,the testing accuracy is:- 0.6450653731671949
#
#
# At random state 68,the training accuracy is:- 0.9791621276492966
# At random state 68,the testing accuracy is:- -0.8286775404119102
#
#
# At random state 69,the training accuracy is:- 0.9792889357600567
# At random state 69,the testing accuracy is:- 0.49875306045055046
#
#
# At random state 70,the training accuracy is:- 0.982907535587971
# At random state 70,the testing accuracy is:- -1.1444146188369815
#
#
# At random state 71,the training accuracy is:- 0.9673750385149569
# At random state 71,the testing accuracy is:- 0.073013966182915
#
#
# At random state 72,the training accuracy is:- 0.9661660985782133
# At random state 72,the testing accuracy is:- 0.6792181922385956
#
#
# At random state 73,the training accuracy is:- 0.9874965403427126
# At random state 73,the testing accuracy is:- 0.558395059469522
#
#
# At random state 74,the training accuracy is:- 0.9818878818152704
# At random state 74,the testing accuracy is:- -0.2602524066587495
#
#
# At random state 75,the training accuracy is:- 0.9849032162873214
# At random state 75,the testing accuracy is:- -0.12273604601912269
#
#
# At random state 76,the training accuracy is:- 0.9865517693186534
# At random state 76,the testing accuracy is:- 0.18473902178216606
#
#
# At random state 77,the training accuracy is:- 0.9799870114540982
# At random state 77,the testing accuracy is:- 0.6264399266926868
#
#
# At random state 78,the training accuracy is:- 0.9702281633631556
# At random state 78,the testing accuracy is:- 0.6552076856028872
#
#
# At random state 79,the training accuracy is:- 0.9685716699475297
# At random state 79,the testing accuracy is:- 0.34050841553194855
#
#
# At random state 80,the training accuracy is:- 0.9940429100160965
# At random state 80,the testing accuracy is:- 0.3272173180151182
#
#
# At random state 81,the training accuracy is:- 0.9824342836641327
# At random state 81,the testing accuracy is:- -0.08397561658793484
#
#
# At random state 82,the training accuracy is:- 0.983758142863545
# At random state 82,the testing accuracy is:- 0.5679888146857429
#
#
# At random state 83,the training accuracy is:- 0.9673368978701474
# At random state 83,the testing accuracy is:- 0.14967251178571062
#
#
# At random state 84,the training accuracy is:- 0.9963624362062966
# At random state 84,the testing accuracy is:- -6.85040495920002
#
#
# At random state 85,the training accuracy is:- 0.9908718366666472
# At random state 85,the testing accuracy is:- 0.645619478285714
#
#
# At random state 86,the training accuracy is:- 0.9576911426215511
# At random state 86,the testing accuracy is:- 0.48027690031121706
#
#
# At random state 87,the training accuracy is:- 0.983862885315315
# At random state 87,the testing accuracy is:- 0.5172459715640624
#
#
# At random state 88,the training accuracy is:- 0.9913141008490519
# At random state 88,the testing accuracy is:- -0.4217151687427636
#
#
# At random state 89,the training accuracy is:- 0.9761230306133234
# At random state 89,the testing accuracy is:- 0.48437647016192376
#
#
# At random state 90,the training accuracy is:- 0.9818505714338792
# At random state 90,the testing accuracy is:- -0.04519244447423598
#
#
# At random state 91,the training accuracy is:- 0.9798597090757025
# At random state 91,the testing accuracy is:- -0.2230354802181711
#
#
# At random state 92,the training accuracy is:- 0.9875746612009421
# At random state 92,the testing accuracy is:- -0.7508827586543931
#
#
# At random state 93,the training accuracy is:- 0.9699265113871981
# At random state 93,the testing accuracy is:- 0.3417300746750359
#
#
# At random state 94,the training accuracy is:- 0.9818929476341259
# At random state 94,the testing accuracy is:- 0.01804849116792384
#
#
# At random state 95,the training accuracy is:- 0.9704698079899166
# At random state 95,the testing accuracy is:- 0.3197501807888832
#
#
# At random state 96,the training accuracy is:- 0.988829335845386
# At random state 96,the testing accuracy is:- 0.7113080609294531
#
#
# At random state 97,the training accuracy is:- 0.9808589752529538
# At random state 97,the testing accuracy is:- -1.1437829949651896
#
#
# At random state 98,the training accuracy is:- 0.9635893267508693
# At random state 98,the testing accuracy is:- 0.7375106635204631
#
#
# At random state 99,the training accuracy is:- 0.9682506458090087
# At random state 99,the testing accuracy is:- 0.74530408228767

# %%
model_name=[]
r2_scores=[]
rmse_value=[]

# %%
#Train Test Split
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.30,random_state=99)

# %%
#Linear Regression
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
r2score=r2_score(y_test,y_pred)*100
print(r2score)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',rmse )
# Out:
# 74.530408228767
# MAE: 5.220824032358817
# MSE: 34.468847530402
# RMSE: 5.871017589004652

# %%
#Lasso Regularization
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV
lasscv=LassoCV(alphas=None, max_iter=1000, normalize=True)
lasscv.fit(x_train,y_train)
alpha=lasscv.alpha_
lasso_reg=Lasso(alpha)
lasso_reg.fit(x_train,y_train)
lasso_reg.score(x_test,y_test)
# Out:
# 0.8482613995213557

# %%
#Ridge Regularization
ridgecv=RidgeCV(normalize=True)
ridgecv.fit(x_train,y_train)
ridgecv.alpha_
ridge_model=Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train,y_train)
ridge_model.score(x_test,y_test)
# Out:
# 0.8191336509250876

# %% [markdown]
# We got around same r2 square using Ridge regression as well. So, it's safe to say there is no overfitting

# %% [markdown]
# So, we can see by using different type of regularization, we are still getting the same r2 score. That means our OLS model has been well trained over the training data and there is no overfitting

# %%
model_name.append('Linear Regression')
r2_scores.append(r2score)
rmse_value.append(rmse)

import pandas as pd
Regression_Scores = pd.DataFrame()
Regression_Scores['Model Name']= model_name
Regression_Scores['r2 Score']=r2_scores
Regression_Scores['RMSE ']=rmse_value

# %%
plt.scatter(x=y_test,y=y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
y_pred=dtr.predict(x_test)

# %%
r2score=r2_score(y_test,y_pred)*100
print(r2score)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',rmse )
# Out:
# 3.037766830870281
# MAE: 9.0
# MSE: 131.22222222222223
# RMSE: 11.455226851626389

# %%
model_name.append('Decision Tree Regressor')
r2_scores.append(r2score)
rmse_value.append(rmse)

import pandas as pd
Regression_Scores = pd.DataFrame()
Regression_Scores['Model Name']= model_name
Regression_Scores['r2 Score']=r2_scores
Regression_Scores['RMSE ']=rmse_value

# %%
plt.scatter(x=y_test,y=y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
#RandomForest Regressor
from sklearn.ensemble import RandomForestRegressor
rdr = RandomForestRegressor()
rdr.fit(x_train,y_train)
y_pred=rdr.predict(x_test)

# %%
r2score=r2_score(y_test,y_pred)*100
print(r2score)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',rmse )
# Out:
# 44.89353858784892
# MAE: 7.690000000000001
# MSE: 74.57741111111112
# RMSE: 8.635821391802352

# %%
model_name.append('Random Forest Regressor')
r2_scores.append(r2score)
rmse_value.append(rmse)

import pandas as pd
Regression_Scores = pd.DataFrame()
Regression_Scores['Model Name']= model_name
Regression_Scores['r2 Score']=r2_scores
Regression_Scores['RMSE ']=rmse_value

# %%
plt.scatter(x=y_test,y=y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
#SVR
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train,y_train)
y_pred = svr.predict(x_test)

# %%
r2score=r2_score(y_test,y_pred)*100
print(r2score)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',rmse )
# Out:
# 5.6638939965983575
# MAE: 8.89631396104065
# MSE: 127.66819679127022
# RMSE: 11.299035215064613

# %%
model_name.append('SVR')
r2_scores.append(r2score)
rmse_value.append(rmse)

import pandas as pd
Regression_Scores = pd.DataFrame()
Regression_Scores['Model Name']= model_name
Regression_Scores['r2 Score']=r2_scores
Regression_Scores['RMSE ']=rmse_value

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada.fit(x_train,y_train)
y_pred=ada.predict(x_test)

# %%
r2score=r2_score(y_test,y_pred)*100
print(r2score)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',rmse )
# Out:
# 42.64741835431492
# MAE: 7.7148148148148135
# MSE: 77.61716049382714
# RMSE: 8.810060186731254

# %%
model_name.append('ADA Boost')
r2_scores.append(r2score)
rmse_value.append(rmse)

import pandas as pd
Regression_Scores = pd.DataFrame()
Regression_Scores['Model Name']= model_name
Regression_Scores['r2 Score']=r2_scores
Regression_Scores['RMSE ']=rmse_value

# %%
Regression_Scores
# Out:
#                 Model Name   r2 Score      RMSE
# 0        Linear Regression  74.530408   5.871018
# 1  Decision Tree Regressor   3.037767  11.455227
# 2  Random Forest Regressor  44.893539   8.635821
# 3                      SVR   5.663894  11.299035
# 4                ADA Boost  42.647418   8.810060

# %% [markdown]
# # Concluding Remarks

# %%
#R2 Score is the highest (74.5) and RMSE value is the loweest (5.87) for Linear Regression, hence we will continue with Linear Regression, but let's check the cv score first

# %%
data = pd.DataFrame({'Y Test':y_test , 'Y Pred':y_pred},columns=['Y Test','Y Pred'])
sns.lmplot(x='Y Test',y='Y Pred',data=data,palette='rainbow')
data.head()
# Out:
#     Y Test     Y Pred
# 23      67  75.333333
# 24      63  68.500000
# 16      98  92.400000
# 12      85  81.500000
# 21      83  90.000000

# %%
#CROSS VALIDATION
from sklearn.model_selection import cross_val_score
scr = cross_val_score(lr,x,y,cv=5)
print("Cross validation score of Linear Regression Model", np.abs(scr.mean()))
scr1 = cross_val_score(ada,x,y,cv=5)
print("Cross validation score of Ada Boost Regressor Model", np.abs(scr1.mean()))
scr2 = cross_val_score(rdr,x,y,cv=5)
print("Cross validation score of Random Forest Regressor Model", np.abs(scr2.mean()))
scr3 = cross_val_score(dtr,x,y,cv=5)
print("Cross validation score of Decision Tree Model", np.abs(scr3.mean()))
scr4 = cross_val_score(svr,x,y,cv=5)
print("Cross validation score of SVR Model", np.abs(scr4.mean()))
# Out:
# Cross validation score of Linear Regression Model 0.34367366910562697
# Cross validation score of Ada Boost Regressor Model 0.8942091285586031
# Cross validation score of Random Forest Regressor Model 0.5400798247323808
# Cross validation score of Decision Tree Model 2.069849946838393
# Cross validation score of SVR Model 0.3735829111537932

# %%
# we will now apply lasso regularisation to remove multicolinearity

# %%
#REGULARIZATION
from sklearn.model_selection import GridSearchCV, cross_val_score
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import Lasso
parameters = {'alpha':[.0001, .001, .01, .1, 1, 10], 'random_state': list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 52.46534861562348

# %% [markdown]
# # Since Linear regression model has the best score, we will finalise the model.

# %% [markdown]
# # SAVE THE MODEL

# %%
#SAVING THE MODEL IN PICKLE FORMAT
#PICKELING OF A FILE OR SERIALIZATION OF A FILE
import joblib
joblib.dump(clf.best_params_,"BaseBall.pkl")
# Out:
# ['BaseBall.pkl']
